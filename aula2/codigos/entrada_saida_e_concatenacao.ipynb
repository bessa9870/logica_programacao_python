# %% [markdown]
# # Interatividade e processamento

# %% [markdown]
#    ## Ferramentas de entrada e saída
# | Função | O quê faz? |
# | :-- | :-- |
# | input | parâmetro usado para ler um valor e atribuir a variável À esquerda |
# | print() | uma função que vai ler e exibir o que estiver dentro dos parênteses |
#
# Além destas, também é possível imprimir o valor da variável chamando o identificador que, dependendo do tipo do dado, vai imprimir entre aspas simples ou aspas duplas.

# %%
nome_usuario = input("Digite seu nome: ")

peso_usuario = float(input("Digite seu peso: "))

print("Imprimindo usando print:")
print(peso_usuario)
print(nome_usuario)

print("Imprimindo usando identificador da variável:")
nome_usuario, peso_usuario
# Out:
# Digite seu nome:  Joao 'Gabriel'
# Digite seu peso:  66
# Imprimindo usando print:
# 66.0
# Joao 'Gabriel'
# Imprimindo usando identificador da variável:
# ("Joao 'Gabriel'", 66.0)

# %% [markdown]
# Aspas simples e aspas duplas em Python são a mesma coisa. É um jogo inteligente que evita conflitos, como por
# exemplo: línguas diferentes (Frases em inglês com ' it's a great day to study), citações "Eu sou o milhor", R7. C.
# E etc.

# %% [markdown]
# ## Concatenar strings
#
# Usamos o + (somar) para concatenar strings.

# %%
nome = 'João'
sobrenome = 'Gabriel'

nome_completo = nome + ' ' + sobrenome

print(nome_completo)
# Out:
# João Gabriel
