# %% [markdown]
# # Meu primeiro código em Pyhton :D

# %%
print("Olá, mundo! Eu sou o João")
# Out:
# Olá, mundo! Eu sou o João

# %% [markdown]
# # Usando o marcador # crio um título
# *Usando o marcador * crio um texto em itálico*
#
# **Usando o marcador ** crio um tezto em negrito**

# %%
print("Escrevendo abaixo do markdown")
# Out:
# Escrevendo abaixo do markdown
